# %% [markdown]
# # TEMP

# %%
import pandas as pd

# %%
"""获取 csv 数据"""
folder_path = "C:/Users/CYLK_/user_data/projects/dealer_management/data/"
file_path = "si_fanruan/销售明细.csv"
file_data = pd.read_csv(folder_path+file_path, keep_default_na=False)

# %%
file_data.head()
# Out:
#                 订单创建时间         销售单号       DRP单号        客户编号  \
# 0  2022-03-25 11:20:40  TCSO_080502              TCC_000190
# 1  2022-01-05 13:41:09  TCSO_083197  2021120234  TCC_000202
# 2  2022-01-05 13:41:09  TCSO_083197  2021120234  TCC_000202
# 3  2022-01-05 13:41:10  TCSO_083197  2021120234  TCC_000202
# 4  2022-01-05 13:41:11  TCSO_083197  2021120234  TCC_000202
#
#                 客户名称          产品编号       产品名称  类别1 WS定制品  销售金额(未税)  销售数量  单位  \
# 0        深圳市桓祥商贸有限公司     Z11103_C2  钢铁壮志 （墨绿）  多元化    NO     65.05     1  Ea
# 1  北京六尾獴科技发展有限公司????  LCS-0013-C02     山海玄冥套装   火机    NO  10867.26     5  ea
# 2  北京六尾獴科技发展有限公司????  LCS-0014-C01     扬子鳄 套装   火机    NO   2771.68     5  ea
# 3  北京六尾獴科技发展有限公司????  LCS-0015-C01     仙缘龟 套装   火机    NO   2771.68     5  ea
# 4  北京六尾獴科技发展有限公司????  LCS-0016-C01     文鳐鱼 套装   火机    NO   2771.68     5  ea
#
#   订单状态 审批状态 订单行状态          池             条码     仓库 是否发货        发货日期
# 0  已开票  已开票   已开票     NBD-SO  6936101531775    DHX    是  2022-03-25
# ...
